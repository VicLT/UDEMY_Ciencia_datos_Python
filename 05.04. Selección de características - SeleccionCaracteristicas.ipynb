# %% [markdown]
# # Ejercicio propuesto

# %% [markdown]
# - Crea un programa SeleccionCaracteristicas.py y aplica los pasos vistos durante esta presentación en el CSV de datos de venta de inmuebles que se te proporciona.
# - Selecciona los 4 parámetros más relevantes relacionados con el precio de venta.
# - También puedes hacerlo en fichero Colab si lo prefieres para visualizarlo mejor todo paso a paso.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("precios_inmuebles.csv", sep=',')
df.head()
# Out:
#    Id   Barrio  MetrosBajo  Metros1P  Metros2P  Habitaciones  Aseos  Anyo  \
# 0   1  CollgCr         856       856       854             3      2  2003
# 1   2  Veenker        1262      1262         0             3      2  1976
# 2   3  CollgCr         920       920       866             3      2  2001
# 3   4  Crawfor         756       961       756             3      1  1915
# 4   5  NoRidge        1145      1145      1053             4      2  2000
#
#    Precio
# 0  208500
# 1  181500
# 2  223500
# 3  140000
# 4  250000

# %%
#df = pd.get_dummies(df, columns=['Barrio'], prefix='barrio', dtype=int)
#df.head()

# %%
df = df.drop('Barrio', axis=1)

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlación precios inmuebles')
plt.show()

# %%
columnas_relevantes = ['MetrosBajo', 'Metros1P', 'Aseos', 'Anyo']
df = df[columnas_relevantes + df['Precio']]
df.head()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipython-input-2892865490.py in <cell line: 0>()
#       1 columnas_relevantes = ['MetrosBajo', 'Metros1P', 'Aseos', 'Anyo']
# ----> 2 df = df[columnas_relevantes + df['Precio']]
#       3 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __radd__(self, other)
#     188     @unpack_zerodim_and_defer("__radd__")
#     189     def __radd__(self, other):
# --> 190         return self._arith_method(other, roperator.radd)
#     191
#     192     @unpack_zerodim_and_defer("__sub__")
#
# ...

# %%
df = df[columnas_relevantes]
df
