# %% [markdown]
# # Ejercicio propuesto

# %% [markdown]
# Crea un programa EstimacionVivienda.py que utilice el CSV de inmuebles que se te proporcionará para construir un mapa de regresión que ayude a estimar el precio final de la vivienda en base a los metros cuadrados de la planta baja.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("precios_inmuebles.csv", sep=',')
sns.regplot(x="MetrosBajo", y="Precio", data=data)
plt.show()
