# %% [markdown]
# # Otras operaciones importantes

# %% [markdown]
# Crea un programa llamado NotasNumpy.py que le pida al usuario una secuencia de notas numéricas separadas por espacios. Con ellas, deberá:

# %% [markdown]
# Crear un array unidimensional con NumPy

# %%
import numpy as np

exit = False

while(not exit):
  try:
    notas = input("Introduzca notas numéticas separadas por espacios: ")
    lista_notas = notas.split()
    array_notas = np.array(lista_notas, dtype=np.int32)
    print(f"\nArray de notas: {array_notas}")
    exit = True
  except Exception as error:
    print(f"\nHa ocurrido un error: {error}.\n")
# Out:
# Introduzca notas numéticas separadas por espacios: 1 9 3 8 8 7 0 10 3 4 4 1 5
#
# Array de notas: [ 1  9  3  8  8  7  0 10  3  4  4  1  5]

# %% [markdown]
# Ordenar las notas de mayor a menor

# %%
array_notas_ordenadas = -np.sort(-array_notas)

print(f"Array de notas ordenadas: {array_notas_ordenadas}")
# Out:
# Array de notas ordenadas: [10  9  8  8  7  5  4  4  3  3  1  1  0]

# %% [markdown]
# Crear un segundo array con las notas aprobadas

# %%
array_notas_aprobadas = array_notas_ordenadas[array_notas_ordenadas >= 5]

print(f"Array de notas aprobadas: {array_notas_aprobadas}")
# Out:
# Array de notas aprobadas: [10  9  8  8  7  5]

# %% [markdown]
# Calcular la media de las notas aprobadas

# %%
media_notas_aprobadas = np.mean(array_notas_aprobadas)

print(f"Nota media de las aprobadas: {media_notas_aprobadas}")
# Out:
# Nota media de las aprobadas: 7.833333333333333
